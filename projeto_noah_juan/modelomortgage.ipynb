# %%
import yfinance as yf
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from bcb import sgs
import datetime as dt

# %%
start_date = dt.datetime(1970, 1, 1)
end_date = dt.datetime.now()

# %%
cdi = sgs.get({'CDI':12}, start='1970-01-01')
ipca = sgs.get({'IPCA':433}, start='2005-01-01')
mortgage30 = web.DataReader('MORTGAGE30US', 'fred',start_date, end_date)
mortgage15 = web.DataReader('MORTGAGE15US', 'fred',start_date, end_date)
dftesouro10 = web.DataReader('DGS10', 'fred',start_date, end_date)
dftesouro2 = web.DataReader('DGS2', 'fred',start_date, end_date)

# %%
mortgage15
# Out:
#             MORTGAGE15US
# DATE
# 1991-08-30          8.77
# 1991-09-06          8.79
# 1991-09-13          8.68
# 1991-09-20          8.62
# 1991-09-27          8.59
# ...                  ...
# 2023-08-03          6.25
# 2023-08-10          6.34
# 2023-08-17          6.46
# 2023-08-24          6.55
# 2023-08-31          6.55
#
# [1671 rows x 1 columns]

# %%
plt.plot(mortgage30.index, mortgage30, label="taxa hip americana 30 anos")
plt.plot(mortgage15.index, mortgage15, label="taxa hip americana 15 anos")
plt.legend()

# %%
plt.plot(dftesouro10.index, dftesouro10, label="treasurie americana 30 anos")
plt.plot(dftesouro2.index, dftesouro2, label="treasurie americana 15 anos")
